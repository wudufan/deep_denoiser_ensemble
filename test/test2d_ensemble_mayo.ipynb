# %%
'''
Test ensemble network on mayo dataset
'''
# Out:
# '\nTest ensemble network on mayo dataset\n'

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import os
import sys
import SimpleITK as sitk
import glob
import h5py
import configparser

# %%
sys.path.append('..')
import CTProjector.projector.ct_projector as ct_projector
import model.unet as unet

# %%
import argparse
import configparser
parser = argparse.ArgumentParser()
parser.add_argument('--prj', default = '/home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/lowdoseCTsets/L291_full_sino.mat')
parser.add_argument('--output', 
                    default = '/home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/deep_denoiser_ensemble/test/mayo_2d_3_layer_mean/debug/L291')
parser.add_argument('--geometry', default = '../geometry_mayo.cfg')
parser.add_argument('--islices', type = int, nargs = 2, default = [0,-1])
parser.add_argument('--nslice_mean', type = int, default=3)
# Note that 1e5 is for single slice noise insertion
parser.add_argument('--N0', type = float, default = 1e5)
parser.add_argument('--dose_rate', type=float, default = 4)

parser.add_argument('--device', type = int, default = 0)
parser.add_argument('--img_norm', type = float, default = 0.019)
parser.add_argument('--train_dir', default = '/home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/deep_denoiser_ensemble/train/mayo_2d_3_layer_mean/')
parser.add_argument('--checkpoint', type=int, default = 25)
parser.add_argument('--tags', default = 'l2_depth_3/dose_rate_2,l2_depth_3/dose_rate_4,l2_depth_3/dose_rate_8,l2_depth_3/dose_rate_16')

parser.add_argument('--checkpoint_smooth', default = 'l2_depth_3/dose_rate_16/25.h5')

parser.add_argument('--vmin', type=float, default = -0.16)
parser.add_argument('--vmax', type=float, default = 0.24)
# for single slice
parser.add_argument('--N0_ref', type=float, default = 2.5e4)
parser.add_argument('--filter', default = 'hann')
parser.add_argument('--margin', type=int, default=96)

if sys.argv[0] != 'test2d_ensemble_mayo.py':
    showplot = True
    args = parser.parse_args(['--device', '0',
                              '--prj', '/home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/lowdoseCTsets/L291_full_sino.mat',
                              '--N0', '1e5',
                              '--dose_rate', '2',
                              '--islices', '22','23',
#                               '--tags', 'l2_depth_3_wgan/dose_rate_2,l2_depth_3_wgan/dose_rate_4,l2_depth_3_wgan/dose_rate_8,l2_depth_3_wgan/dose_rate_16',
                             ])
else:
    showplot = False
    args = parser.parse_args()

for k in vars(args):
    print (k, '=', getattr(args, k))
# Out:
# prj = /home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/lowdoseCTsets/L291_full_sino.mat
# output = /home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/deep_denoiser_ensemble/test/mayo_2d_3_layer_mean/debug/L291
# geometry = ../geometry_mayo.cfg
# islices = [22, 23]
# nslice_mean = 3
# N0 = 100000.0
# dose_rate = 2.0
# device = 0
# img_norm = 0.019
# train_dir = /home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/deep_denoiser_ensemble/train/mayo_2d_3_layer_mean/
# checkpoint = 25
# tags = l2_depth_3/dose_rate_2,l2_depth_3/dose_rate_4,l2_depth_3/dose_rate_8,l2_depth_3/dose_rate_16
# checkpoint_smooth = l2_depth_3/dose_rate_16/25.h5
# vmin = -0.16
# vmax = 0.24
# N0_ref = 25000.0
# filter = hann
# margin = 96

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '%d'%args.device
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
print ('[Geometry]')
projector = ct_projector.ct_projector()
projector.from_file(args.geometry)
projector.nv = 1
for k in vars(projector):
    print (k, '=', getattr(projector, k))
# Out:
# [Geometry]
# nview = 2304
# nu = 736
# nv = 1
# nx = 640
# ny = 640
# nz = 1
# dx = 0.75
# dy = 0.75
# dz = 1.0
# cx = 0
# cy = 0
# cz = 0
# dsd = 1086.5
# dso = 595.0
# du = 1.2858
# dv = 1.0
# off_u = -1.125
# off_v = 0
# geometry = <configparser.ConfigParser object at 0x7f25f8879880>

# %%
print ('Loading data...', end='', flush=True)
with h5py.File(args.prj, 'r') as f:
    prj = f['sino']
    if args.islices[0] < args.islices[1]:
        prj = np.copy(prj[args.islices[0] * args.nslice_mean:args.islices[1]*args.nslice_mean])
    else:
        prj = np.copy(prj[:prj.shape[0]//args.nslice_mean*args.nslice_mean])
print ('Done', flush=True)

# take layer-means
prj = prj.reshape([-1, args.nslice_mean, prj.shape[1], prj.shape[2]]).mean(1)
# reshape
prj = prj[:, :, np.newaxis, :] / args.img_norm

if args.N0 > 0:
    print ('Adding noise...', end='', flush=True)
    
    N0 = args.N0 * args.nslice_mean
    prj = prj + np.sqrt((1 - 1 / args.dose_rate) * args.dose_rate * np.exp(prj * args.img_norm) / N0) * np.random.normal(size = prj.shape) / args.img_norm
    prj = prj.astype(np.float32)
    
    print ('Done', flush=True)
else:
    print ('Use original projection', flush=True)
# Out:
# Loading data...Done
# Adding noise...Done

# %%
def fbp_with_noise_estimation(prj, projector, args):
    '''
    Do FBP and use Noise2Noise to estimate the noise pattern
    '''
    angles = projector.get_angles()
    
    inds_offset = np.random.randint(0, 2, prj.shape[1]//2)
    inds1 = np.arange(0, prj.shape[1], 2) + inds_offset
    inds2 = np.arange(0, prj.shape[1], 2) + (1 - inds_offset)
    fprj = projector.ramp_filter(prj, args.filter)
    img1 = projector.fbp_fan_bp(np.copy(fprj[:, inds1, ...], 'C'), angles[inds1]) * 2
    img2 = projector.fbp_fan_bp(np.copy(fprj[:, inds2, ...], 'C'), angles[inds2]) * 2
    
    fbp = (img1 + img2) / 2 - 1
    noise = (img1 - img2) / 2
    
    return fbp, noise

# %%
def estimate_smooth_image(fbp, args):
    model = tf.keras.models.load_model(os.path.join(args.train_dir, args.checkpoint_smooth))
    smooth = model.predict(fbp[:, 0, :, :, np.newaxis])[..., 0]
    smooth = smooth[:, np.newaxis, :, :]
    
    return smooth

# %%
def estimate_noise_level(smooth, noise, projector, args):
    '''
    Estimate the noise level using forward projection
    '''
    # estimate the noise level of reference image
    angles = projector.get_angles()
    fp = projector.siddon_fan_fp(smooth + 1, angles)
    N0 = args.N0_ref * args.nslice_mean / np.mean(np.exp(-fp * args.img_norm))
    
    # noise insertion
    fp_noisy = -np.log(np.random.poisson(N0 * np.exp(-fp * args.img_norm)) / N0) / args.img_norm
    
    # noise level estimation
    recon_noiseless = projector.fbp_fan_bp(projector.ramp_filter(fp, args.filter), angles) - 1
    recon_noisy = projector.fbp_fan_bp(projector.ramp_filter(fp_noisy, args.filter), angles) - 1
    
    m = args.margin
    noise_ratio = np.linalg.norm((recon_noisy - recon_noiseless)[..., m:-m, m:-m]) / np.linalg.norm(noise[..., m:-m, m:-m])
    
    return noise_ratio

# %%
def pred_meta_images(img, args):
    '''
    Predict the meta images to ensemble
    '''
    metas = [img]
    for tag in args.tags.split(','):
        model = tf.keras.models.load_model(os.path.join(args.train_dir, tag, '%d.h5'%args.checkpoint))
        pred = model.predict(img[:, 0, :, :, np.newaxis])[..., 0]
        pred = pred[:, np.newaxis, :, :]
        
        metas.append(pred)
    
    return np.array(metas)

# %%
def preprocess(x, args):
    return x[..., args.margin:-args.margin, args.margin:-args.margin]

def ensemble_l2(target, metas, args):
    '''
    ensemble metas to target by minimizing the l2 distance
    ''' 
    
    y = preprocess(target, args)
    xs = [preprocess(m, args) for m in metas]
    
    M = np.zeros([len(metas), len(metas)])
    b = np.zeros([len(metas)])
    
    for k in range(len(xs)):
        b[k] = np.sum(y * xs[k])
        for j in range(len(xs)):
            M[k, j] = np.sum(xs[k] * xs[j])
    
    c = np.linalg.solve(M, b)
    
    return c.astype(np.float32)

def ensemble_l2_min_3(target, metas, args):
    '''
    ensemble metas to target by minimizing the l2 distance
    ''' 
    
    y = preprocess(target, args)
    xs = [preprocess(m, args) for m in metas]

    # select the components around the minimum
    errs = [np.linalg.norm(x - y) for x in xs]
    min_comp = np.argmin(errs)
    valid_cols = [min_comp - 1, min_comp, min_comp+1]
    valid_cols = [c for c in valid_cols if c >=0 and c < len(metas)]

    xs = [xs[i] for i in valid_cols]

    M = np.zeros([len(xs), len(xs)])
    b = np.zeros([len(xs)])
    
    for k in range(len(xs)):
        b[k] = np.sum(y * xs[k])
        for j in range(len(xs)):
            M[k, j] = np.sum(xs[k] * xs[j])
    
    c = np.linalg.solve(M, b)

    # fill other components with zero
    coef = np.zeros(len(metas))
    for i, col in enumerate(valid_cols):
        coef[col] = c[i]
    
    return coef.astype(np.float32)

# %%
import time

# %%
K.clear_session()
np.random.seed(0)

preds = []
coefs = []

print (len(prj), flush=True)
for islice in range(prj.shape[0]):
    print (islice, end=',', flush=True)
    
    t1 = time.time()
    fbp, noise = fbp_with_noise_estimation(prj[[islice], ...], projector, args)
    t2 = time.time()
    smooth = estimate_smooth_image(fbp, args)
    noise_ratio = estimate_noise_level(smooth, noise, projector, args)
    t3 = time.time()

    # predict the meta images
    fbp_metas = pred_meta_images(fbp, args)
    t4 = time.time()
    smooth_metas = pred_meta_images(smooth + noise, args)
    t5 = time.time()

    # print (t2 - t1, t3 - t2, t4 - t3, t5 - t4)
    
    # get the combination coefficients
    c = ensemble_l2(smooth + noise_ratio * noise, smooth_metas, args)
    # c = ensemble_l2_min_3(smooth + noise_ratio * noise, smooth_metas, args)
    # c = np.array([0, 1, 0, 0, 0], np.float32)

    # combine the fbp metas to get the result
    pred = np.sum(fbp_metas * c[:, np.newaxis, np.newaxis, np.newaxis, np.newaxis], 0)
    
    preds.append(pred)
    coefs.append(c)
print ('')

preds = np.array(preds)
coefs = np.array(coefs)
# Out:
# 34
# 0,0.5560789108276367 5.232092618942261 4.0425403118133545 4.0593156814575195
# 1,0.1053307056427002 1.3251702785491943 4.163928747177124 3.535667896270752
# 2,0.09673094749450684 1.2745740413665771 4.187327861785889 3.9626307487487793
# 3,0.13694214820861816 1.357100248336792 4.348754405975342 4.284168481826782
# 4,0.09583497047424316 1.2060861587524414 3.992560625076294 4.125749111175537
# 5,0.10050129890441895 1.2878668308258057 3.8622324466705322 3.94587779045105
# 6,0.10828828811645508 1.4267210960388184 3.9488525390625 4.226092100143433
# 7,0.09600663185119629 1.2142550945281982 4.3365936279296875 3.3585708141326904
# 8,0.10175943374633789 1.2697203159332275 3.821294069290161 3.866999387741089
# 9,0.10718607902526855 1.91524076461792 3.8564159870147705 4.004223346710205
# 10,0.10917282104492188 1.4248013496398926 4.0898144245147705 4.285645008087158
# 11,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-5ad06bd03417> in <module>
#      12     fbp, noise = fbp_with_noise_estimation(prj[[islice], ...], projector, args)
#      13     t2 = time.time()
# ---> 14     smooth = estimate_smooth_image(fbp, args)
#      15     noise_ratio = estimate_noise_level(smooth, noise, projector, args)
#      16     t3 = time.time()
#
# <ipython-input-9-c9301c645b3b> in estimate_smooth_image(fbp, args)
#       1 def estimate_smooth_image(fbp, args):
#       2     model = tf.keras.models.load_model(os.path.join(args.train_dir, args.checkpoint_smooth))
# ----> 3     smooth = model.predict(fbp[:, 0, :, :, np.newaxis])[..., 0]
#       4     smooth = smooth[:, np.newaxis, :, :]
#       5
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1284       callbacks.on_predict_end()
#    1285     all_outputs = nest.map_structure_up_to(batch_outputs, concat, outputs)
# -> 1286     return tf_utils.to_numpy_or_python_type(all_outputs)
#    1287
#    1288   def reset_metrics(self):
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# ~/miniconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
sitk_ref = sitk.ReadImage('/home/local/PARTNERS/dw640/mnt/women_health_internal/dufan.wu/deep_denoiser_ensemble/test/mayo_2d_3_layer_mean/debug_full/L291.nii')
ref = sitk.GetArrayFromImage(sitk_ref).astype(np.float32) / 1000

# %%
rmse = np.sqrt(np.mean((preds[:, 0, 0, ...] - ref[args.islices[0]:args.islices[1]])**2))
print (rmse * 1000)
print (coefs)
# Out:
# 11.479726992547512
# [[ 0.65357804 -0.09356224  0.09220821  0.14248571  0.20389302]]

# %%
plt.figure(figsize=[16,8])
plt.subplot(121); plt.imshow(preds[0, 0, 0, args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)
plt.subplot(122); plt.imshow(ref[22, args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)

# %%
rmse = np.sqrt(np.mean((preds[:, 0, 0, ...] - ref[args.islices[0]:args.islices[1]])**2))
print (rmse * 1000)
print (coefs)
# Out:
# 11.508181691169739
# [[ 0.61188716 -0.19198647  0.5796632   0.          0.        ]]

# %%
plt.figure(figsize=[16,8])
plt.subplot(121); plt.imshow(preds[0, 0, 0, args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)
plt.subplot(122); plt.imshow(ref[args.islices[0], args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)

# %%
# save the results
print ('Writing results...', end='', flush=True)

if not os.path.exists(os.path.dirname(args.output)):
    os.makedirs(os.path.dirname(args.output))

# running configuration
cfg = configparser.ConfigParser()
cfg.add_section('Test')
for k in vars(args):
    cfg['Test'][k] = str(getattr(args, k))
with open(args.output + '.cfg', 'w') as f:
    cfg.write(f)

# coefficients
np.save(args.output + '_coefs.npy', coefs)

# image
sitk_img = sitk.GetImageFromArray((preds.squeeze() * 1000).astype(np.int16))
sitk_img.SetSpacing([float(projector.dx), float(projector.dy), float(projector.dz * args.nslice_mean)])
sitk.WriteImage(sitk_img, args.output + '.nii')

print ('Done', flush=True)
# Out:
# Writing results...Done

# %%
if showplot:
    plt.figure(figsize=[16,8])
    plt.subplot(121);plt.imshow(fbp[0,0,args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)
    plt.subplot(122);plt.imshow(pred[0,0,args.margin:-args.margin, args.margin:-args.margin], 'gray', vmin = args.vmin, vmax = args.vmax)
